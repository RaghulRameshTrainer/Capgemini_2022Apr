# %%
import pandas as pd
import numpy as np

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.6/10.6 MB 1.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 503.5/503.5 KB 1.3 MB/s eta 0:00:00
# ...

# %%
df=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\companytest.csv')

# %%
df.shape
# Out:
# (30, 3)

# %%
df.head()
# Out:
#     Company   Age  Salary
# 0  Infosys'  20.0     NaN
# 1       CTS  30.0     NaN
# 2  Infosys'  35.0  2300.0
# 3       CTS  40.0  3000.0
# 4   Infosys  23.0  4000.0

# %%
df.tail()
# Out:
#     Company   Age  Salary
# 25      CTS  23.0  8943.0
# 26  Infosys  34.0  8345.0
# 27      TCS  45.0  9284.0
# 28      TCS  23.0     NaN
# 29      TCS  35.0  2034.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  27 non-null     object
#  1   Age      26 non-null     float64
#  2   Salary   23 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 848.0+ bytes

# %%
df
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df.iloc[10:21,0:2]
# Out:
#     Company   Age
# 10      TCS  23.0
# 11      TCS  34.0
# 12      TCS  45.0
# 13      TCS  18.0
# 14      NaN  40.0
# 15  Infosys  23.0
# 16      CTS  23.0
# 17  Infosys  34.0
# 18      NaN  22.0
# 19      CTS  32.0
# 20  Infosys  37.0

# %%
df.iloc[20,0]
# Out:
# 'Infosys'

# %%
df.loc[20:25,['Salary','Company']]
# Out:
#     Salary  Company
# 20  3045.0  Infosys
# 21  3184.0      CTS
# 22  4824.0  Infosys
# 23  5835.0      CTS
# 24  7084.0      NaN
# 25  8943.0      CTS

# %%
df.iloc[20:22,0:1]
# Out:
#     Company
# 20  Infosys
# 21      CTS

# %%
df.loc[20:21,['Company']]
# Out:
#     Company
# 20  Infosys
# 21      CTS

# %%
df
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df.loc[df['Company'].isin(['Infosys','CTS'])]
# Out:
#     Company   Age  Salary
# 1       CTS  30.0     NaN
# 3       CTS  40.0  3000.0
# 4   Infosys  23.0  4000.0
# 5       CTS   NaN  5000.0
# 6   Infosys   NaN  6000.0
# 8   Infosys  34.0  8000.0
# 15  Infosys  23.0  3000.0
# 16      CTS  23.0  3030.0
# 17  Infosys  34.0  5000.0
# 19      CTS  32.0     NaN
# 20  Infosys  37.0  3045.0
# 21      CTS  50.0  3184.0
# 22  Infosys  21.0  4824.0
# 23      CTS   NaN  5835.0
# 25      CTS  23.0  8943.0
# 26  Infosys  34.0  8345.0

# %%
df.loc[(df['Salary']>7000) & (df['Age']>30)&(df['Company'] != 'Infosys')]
# Out:
#    Company   Age  Salary
# 9      TCS  45.0  9000.0
# 27     TCS  45.0  9284.0

# %%
df.loc[(df['Company'].isna()) | (df['Age'].isna()) | (df['Salary'].isna())]
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 10       TCS  23.0     NaN
# 12       TCS  45.0     NaN
# 14       NaN  40.0  3000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 28       TCS  23.0     NaN

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df['Company'].unique()
# Out:
# array(["Infosys'", 'CTS', 'Infosys', "CTS'", 'TCS', nan], dtype=object)

# %%
df['Company']=df['Company'].replace({"Infosys'":'Infosys',"CTS'":'CTS'})

# %%
df['Company'].unique()
# Out:
# array(['Infosys', 'CTS', 'TCS', nan], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# Infosys    10
# CTS         9
# TCS         8
# Name: Company, dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 4

# %%
df['Company'].isna().sum()
# Out:
# 3

# %%
df['Company'].mode()
# Out:
# 0    Infosys
# Name: Company, dtype: object

# %%
df['Company'].fillna('Infosys',inplace=True)

# %%
df['Company'].isna().sum()
# Out:
# 0

# %%
df['Age'].min()
# Out:
# 18.0

# %%
df['Age'].max()
# Out:
# 50.0

# %%
df['Age'].mean()
# Out:
# 31.23076923076923

# %%
df['Age'].mode()
# Out:
# 0    23.0
# Name: Age, dtype: float64

# %%
df['Age'].agg([min,max,sum])
# Out:
# min     18.000000
# max     50.000000
# sum    936.923077
# Name: Age, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# 23.0    7
# 34.0    4
# 45.0    3
# 35.0    2
# 40.0    2
# 20.0    1
# 30.0    1
# 18.0    1
# 22.0    1
# 32.0    1
# 37.0    1
# 50.0    1
# 21.0    1
# Name: Age, dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 4

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df
# Out:
#     Company        Age  Salary
# 0   Infosys  20.000000     NaN
# 1       CTS  30.000000     NaN
# 2   Infosys  35.000000  2300.0
# 3       CTS  40.000000  3000.0
# 4   Infosys  23.000000  4000.0
# 5       CTS  31.230769  5000.0
# 6   Infosys  31.230769  6000.0
# 7       CTS  23.000000  7000.0
# 8   Infosys  34.000000  8000.0
# 9       TCS  45.000000  9000.0
# 10      TCS  23.000000     NaN
# 11      TCS  34.000000  1089.0
# 12      TCS  45.000000     NaN
# 13      TCS  18.000000  1234.0
# 14  Infosys  40.000000  3000.0
# 15  Infosys  23.000000  3000.0
# 16      CTS  23.000000  3030.0
# 17  Infosys  34.000000  5000.0
# 18  Infosys  22.000000     NaN
# 19      CTS  32.000000     NaN
# 20  Infosys  37.000000  3045.0
# 21      CTS  50.000000  3184.0
# 22  Infosys  21.000000  4824.0
# 23      CTS  31.230769  5835.0
# 24  Infosys  31.230769  7084.0
# 25      CTS  23.000000  8943.0
# 26  Infosys  34.000000  8345.0
# 27      TCS  45.000000  9284.0
# 28      TCS  23.000000     NaN
# ...

# %%
df1=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\companytest.csv')

# %%
df1
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df1.dropna(subset=['Company','Salary'])
# Out:
#      Company   Age  Salary
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 11       TCS  34.0  1089.0
# 13       TCS  18.0  1234.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 29       TCS  35.0  2034.0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary':'Pay'},inplace=True)

# %%
df
# Out:
#     Company        Age     Pay
# 0   Infosys  20.000000     NaN
# 1       CTS  30.000000     NaN
# 2   Infosys  35.000000  2300.0
# 3       CTS  40.000000  3000.0
# 4   Infosys  23.000000  4000.0
# 5       CTS  31.230769  5000.0
# 6   Infosys  31.230769  6000.0
# 7       CTS  23.000000  7000.0
# 8   Infosys  34.000000  8000.0
# 9       TCS  45.000000  9000.0
# 10      TCS  23.000000     NaN
# 11      TCS  34.000000  1089.0
# 12      TCS  45.000000     NaN
# 13      TCS  18.000000  1234.0
# 14  Infosys  40.000000  3000.0
# 15  Infosys  23.000000  3000.0
# 16      CTS  23.000000  3030.0
# 17  Infosys  34.000000  5000.0
# 18  Infosys  22.000000     NaN
# 19      CTS  32.000000     NaN
# 20  Infosys  37.000000  3045.0
# 21      CTS  50.000000  3184.0
# 22  Infosys  21.000000  4824.0
# 23      CTS  31.230769  5835.0
# 24  Infosys  31.230769  7084.0
# 25      CTS  23.000000  8943.0
# 26  Infosys  34.000000  8345.0
# 27      TCS  45.000000  9284.0
# 28      TCS  23.000000     NaN
# ...

# %%
df.groupby('Company')['Pay'].sum()
# Out:
# Company
# CTS        35992.0
# Infosys    54598.0
# TCS        22641.0
# Name: Pay, dtype: float64

# %%
df.groupby('Company')['Age'].agg([min,max])
# Out:
#           min   max
# Company
# CTS      23.0  50.0
# Infosys  20.0  40.0
# TCS      18.0  45.0

# %%
df.groupby(['Company','Age'],sort=True)['Pay'].sum()
# Out:
# Company  Age
# CTS      23.000000    18973.0
#          30.000000        0.0
#          31.230769    10835.0
#          32.000000        0.0
#          40.000000     3000.0
#          50.000000     3184.0
# Infosys  20.000000        0.0
#          21.000000     4824.0
#          22.000000        0.0
#          23.000000     7000.0
#          31.230769    13084.0
#          34.000000    21345.0
#          35.000000     2300.0
#          37.000000     3045.0
#          40.000000     3000.0
# TCS      18.000000     1234.0
#          23.000000        0.0
#          34.000000     1089.0
#          35.000000     2034.0
#          45.000000    18284.0
# Name: Pay, dtype: float64

# %%
df
# Out:
#     Company        Age     Pay
# 0   Infosys  20.000000     NaN
# 1       CTS  30.000000     NaN
# 2   Infosys  35.000000  2300.0
# 3       CTS  40.000000  3000.0
# 4   Infosys  23.000000  4000.0
# 5       CTS  31.230769  5000.0
# 6   Infosys  31.230769  6000.0
# 7       CTS  23.000000  7000.0
# 8   Infosys  34.000000  8000.0
# 9       TCS  45.000000  9000.0
# 10      TCS  23.000000     NaN
# 11      TCS  34.000000  1089.0
# 12      TCS  45.000000     NaN
# 13      TCS  18.000000  1234.0
# 14  Infosys  40.000000  3000.0
# 15  Infosys  23.000000  3000.0
# 16      CTS  23.000000  3030.0
# 17  Infosys  34.000000  5000.0
# 18  Infosys  22.000000     NaN
# 19      CTS  32.000000     NaN
# 20  Infosys  37.000000  3045.0
# 21      CTS  50.000000  3184.0
# 22  Infosys  21.000000  4824.0
# 23      CTS  31.230769  5835.0
# 24  Infosys  31.230769  7084.0
# 25      CTS  23.000000  8943.0
# 26  Infosys  34.000000  8345.0
# 27      TCS  45.000000  9284.0
# 28      TCS  23.000000     NaN
# ...

# %%
df.sort_values(['Age','Company'])
# Out:
#     Company        Age     Pay
# 13      TCS  18.000000  1234.0
# 0   Infosys  20.000000     NaN
# 22  Infosys  21.000000  4824.0
# 18  Infosys  22.000000     NaN
# 7       CTS  23.000000  7000.0
# 16      CTS  23.000000  3030.0
# 25      CTS  23.000000  8943.0
# 4   Infosys  23.000000  4000.0
# 15  Infosys  23.000000  3000.0
# 10      TCS  23.000000     NaN
# 28      TCS  23.000000     NaN
# 1       CTS  30.000000     NaN
# 5       CTS  31.230769  5000.0
# 23      CTS  31.230769  5835.0
# 6   Infosys  31.230769  6000.0
# 24  Infosys  31.230769  7084.0
# 19      CTS  32.000000     NaN
# 8   Infosys  34.000000  8000.0
# 17  Infosys  34.000000  5000.0
# 26  Infosys  34.000000  8345.0
# 11      TCS  34.000000  1089.0
# 2   Infosys  35.000000  2300.0
# 29      TCS  35.000000  2034.0
# 20  Infosys  37.000000  3045.0
# 3       CTS  40.000000  3000.0
# 14  Infosys  40.000000  3000.0
# 9       TCS  45.000000  9000.0
# 12      TCS  45.000000     NaN
# 27      TCS  45.000000  9284.0
# ...

# %%
df['Elder']=np.where(df['Age']>25,'Yes','No')

# %%
df.head()
# Out:
#    Company   Age     Pay Category Elder
# 0  Infosys  20.0     NaN    Elder    No
# 1      CTS  30.0     NaN    Elder   Yes
# 2  Infosys  35.0  2300.0    Elder   Yes
# 3      CTS  40.0  3000.0    Elder   Yes
# 4  Infosys  23.0  4000.0    Elder    No

# %%
df.drop('Category',axis=1,inplace=True)

# %%
df
# Out:
#     Company        Age     Pay Elder
# 0   Infosys  20.000000     NaN    No
# 1       CTS  30.000000     NaN   Yes
# 2   Infosys  35.000000  2300.0   Yes
# 3       CTS  40.000000  3000.0   Yes
# 4   Infosys  23.000000  4000.0    No
# 5       CTS  31.230769  5000.0   Yes
# 6   Infosys  31.230769  6000.0   Yes
# 7       CTS  23.000000  7000.0    No
# 8   Infosys  34.000000  8000.0   Yes
# 9       TCS  45.000000  9000.0   Yes
# 10      TCS  23.000000     NaN    No
# 11      TCS  34.000000  1089.0   Yes
# 12      TCS  45.000000     NaN   Yes
# 13      TCS  18.000000  1234.0    No
# 14  Infosys  40.000000  3000.0   Yes
# 15  Infosys  23.000000  3000.0    No
# 16      CTS  23.000000  3030.0    No
# 17  Infosys  34.000000  5000.0   Yes
# 18  Infosys  22.000000     NaN    No
# 19      CTS  32.000000     NaN   Yes
# 20  Infosys  37.000000  3045.0   Yes
# 21      CTS  50.000000  3184.0   Yes
# 22  Infosys  21.000000  4824.0    No
# 23      CTS  31.230769  5835.0   Yes
# ...

# %%
df.to_csv(r'C:\Users\RaghulRamesh\Downloads\companytest_edited.csv',index=False)
