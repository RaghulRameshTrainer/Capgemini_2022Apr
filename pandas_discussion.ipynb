# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
#      ---------------------------------------- 10.6/10.6 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raghulramesh\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raghulramesh\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.22.3)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      -------------------------------------- 503.5/503.5 KB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\raghulramesh\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.4.2 pytz-2022.1

# %%
df=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\companytest.csv')

# %%
df.shape
# Out:
# (30, 3)

# %%
df.head()
# Out:
#     Company   Age  Salary
# 0  Infosys'  20.0     NaN
# 1       CTS  30.0     NaN
# 2  Infosys'  35.0  2300.0
# 3       CTS  40.0  3000.0
# 4   Infosys  23.0  4000.0

# %%
df.tail()
# Out:
#     Company   Age  Salary
# 25      CTS  23.0  8943.0
# 26  Infosys  34.0  8345.0
# 27      TCS  45.0  9284.0
# 28      TCS  23.0     NaN
# 29      TCS  35.0  2034.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  27 non-null     object
#  1   Age      26 non-null     float64
#  2   Salary   23 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 848.0+ bytes

# %%
df
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df.iloc[10:21,0:2]
# Out:
#     Company   Age
# 10      TCS  23.0
# 11      TCS  34.0
# 12      TCS  45.0
# 13      TCS  18.0
# 14      NaN  40.0
# 15  Infosys  23.0
# 16      CTS  23.0
# 17  Infosys  34.0
# 18      NaN  22.0
# 19      CTS  32.0
# 20  Infosys  37.0

# %%
df.iloc[20,0]
# Out:
# 'Infosys'

# %%
df.loc[20:25,['Salary','Company']]
# Out:
#     Salary  Company
# 20  3045.0  Infosys
# 21  3184.0      CTS
# 22  4824.0  Infosys
# 23  5835.0      CTS
# 24  7084.0      NaN
# 25  8943.0      CTS

# %%
df.iloc[20:22,0:1]
# Out:
#     Company
# 20  Infosys
# 21      CTS

# %%
df.loc[20:21,['Company']]
# Out:
#     Company
# 20  Infosys
# 21      CTS

# %%
df
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df.loc[df['Company'].isin(['Infosys','CTS'])]
# Out:
#     Company   Age  Salary
# 1       CTS  30.0     NaN
# 3       CTS  40.0  3000.0
# 4   Infosys  23.0  4000.0
# 5       CTS   NaN  5000.0
# 6   Infosys   NaN  6000.0
# 8   Infosys  34.0  8000.0
# 15  Infosys  23.0  3000.0
# 16      CTS  23.0  3030.0
# 17  Infosys  34.0  5000.0
# 19      CTS  32.0     NaN
# 20  Infosys  37.0  3045.0
# 21      CTS  50.0  3184.0
# 22  Infosys  21.0  4824.0
# 23      CTS   NaN  5835.0
# 25      CTS  23.0  8943.0
# 26  Infosys  34.0  8345.0

# %%
df.loc[(df['Salary']>7000) & (df['Age']>30)&(df['Company'] != 'Infosys')]
# Out:
#    Company   Age  Salary
# 9      TCS  45.0  9000.0
# 27     TCS  45.0  9284.0

# %%
df.loc[(df['Company'].isna()) | (df['Age'].isna()) | (df['Salary'].isna())]
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 10       TCS  23.0     NaN
# 12       TCS  45.0     NaN
# 14       NaN  40.0  3000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 28       TCS  23.0     NaN

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df['Company'].unique()
# Out:
# array(["Infosys'", 'CTS', 'Infosys', "CTS'", 'TCS', nan], dtype=object)

# %%
df['Company']=df['Company'].replace({"Infosys'":'Infosys',"CTS'":'CTS'})

# %%
df['Company'].unique()
# Out:
# array(['Infosys', 'CTS', 'TCS', nan], dtype=object)

# %%
df['Company'].value_counts()
# Out:
# Infosys    10
# CTS         9
# TCS         8
# Name: Company, dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 4

# %%
df['Company'].isna().sum()
# Out:
# 3

# %%
df['Company'].mode()
# Out:
# 0    Infosys
# Name: Company, dtype: object

# %%
df['Company'].fillna('Infosys',inplace=True)

# %%
df['Company'].isna().sum()
# Out:
# 0

# %%
df['Age'].min()
# Out:
# 18.0

# %%
df['Age'].max()
# Out:
# 50.0

# %%
df['Age'].mean()
# Out:
# 31.23076923076923

# %%
df['Age'].mode()
# Out:
# 0    23.0
# Name: Age, dtype: float64

# %%
df['Age'].agg({'min','max','mode','std','mean'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:422, in Apply.agg_list_like(self)
#     421 try:
# --> 422     concatenated = concat(results, keys=keys, axis=1, sort=False)
#     423 except TypeError as err:
#     424     # we are concatting non-NDFrame objects,
#     425     # e.g. a list of scalars
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
# --> 347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#     350     ignore_index=ignore_index,
#     351     join=join,
#     352     keys=keys,
#     353     levels=levels,
#     354     names=names,
#     355     verify_integrity=verify_integrity,
#     356     copy=copy,
#     357     sort=sort,
#     358 )
#     360 return op.get_result()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\concat.py:437, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     433     msg = (
#     434         f"cannot concatenate object of type '{type(obj)}'; "
#     435         "only Series and DataFrame objs are valid"
#     436     )
# --> 437     raise TypeError(msg)
#     439 ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'numpy.float64'>'; only Series and DataFrame objs are valid
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 df['Age'].agg({'min','max','mode','std','mean'})
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4303, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4300     func = dict(kwargs.items())
#    4302 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4303 result = op.agg()
#    4304 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1085, in SeriesApply.agg(self)
#    1084 def agg(self):
# -> 1085     result = super().agg()
#    1086     if result is None:
#    1087         f = self.f
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:171, in Apply.agg(self)
#     168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
# --> 171     return self.agg_list_like()
#     173 if callable(arg):
#     174     f = com.get_cython_func(arg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:430, in Apply.agg_list_like(self)
#     428     result = Series(results, index=keys, name=obj.name)
#     429     if is_nested_object(result):
# --> 430         raise ValueError(
#     431             "cannot combine transform and aggregation operations"
#     432         ) from err
#     433     return result
#     434 else:
#     435     # Concat uses the first index to determine the final indexing order.
#     436     # The union of a shorter first index with the other indices causes
#     437     # the index sorting to be different from the order of the aggregating
#     438     # functions. Reindex if this is the case.
#
# ValueError: cannot combine transform and aggregation operations

# %%
df['Age'].value_counts()
# Out:
# 23.0    7
# 34.0    4
# 45.0    3
# 35.0    2
# 40.0    2
# 20.0    1
# 30.0    1
# 18.0    1
# 22.0    1
# 32.0    1
# 37.0    1
# 50.0    1
# 21.0    1
# Name: Age, dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 4

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df
# Out:
#     Company        Age  Salary
# 0   Infosys  20.000000     NaN
# 1       CTS  30.000000     NaN
# 2   Infosys  35.000000  2300.0
# 3       CTS  40.000000  3000.0
# 4   Infosys  23.000000  4000.0
# 5       CTS  31.230769  5000.0
# 6   Infosys  31.230769  6000.0
# 7       CTS  23.000000  7000.0
# 8   Infosys  34.000000  8000.0
# 9       TCS  45.000000  9000.0
# 10      TCS  23.000000     NaN
# 11      TCS  34.000000  1089.0
# 12      TCS  45.000000     NaN
# 13      TCS  18.000000  1234.0
# 14  Infosys  40.000000  3000.0
# 15  Infosys  23.000000  3000.0
# 16      CTS  23.000000  3030.0
# 17  Infosys  34.000000  5000.0
# 18  Infosys  22.000000     NaN
# 19      CTS  32.000000     NaN
# 20  Infosys  37.000000  3045.0
# 21      CTS  50.000000  3184.0
# 22  Infosys  21.000000  4824.0
# 23      CTS  31.230769  5835.0
# 24  Infosys  31.230769  7084.0
# 25      CTS  23.000000  8943.0
# 26  Infosys  34.000000  8345.0
# 27      TCS  45.000000  9284.0
# 28      TCS  23.000000     NaN
# 29      TCS  35.000000  2034.0

# %%
df1=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\companytest.csv')

# %%
df1
# Out:
#      Company   Age  Salary
# 0   Infosys'  20.0     NaN
# 1        CTS  30.0     NaN
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 10       TCS  23.0     NaN
# 11       TCS  34.0  1089.0
# 12       TCS  45.0     NaN
# 13       TCS  18.0  1234.0
# 14       NaN  40.0  3000.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 18       NaN  22.0     NaN
# 19       CTS  32.0     NaN
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 24       NaN   NaN  7084.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 28       TCS  23.0     NaN
# 29       TCS  35.0  2034.0

# %%
df1.dropna(subset=['Company','Salary'])
# Out:
#      Company   Age  Salary
# 2   Infosys'  35.0  2300.0
# 3        CTS  40.0  3000.0
# 4    Infosys  23.0  4000.0
# 5        CTS   NaN  5000.0
# 6    Infosys   NaN  6000.0
# 7       CTS'  23.0  7000.0
# 8    Infosys  34.0  8000.0
# 9        TCS  45.0  9000.0
# 11       TCS  34.0  1089.0
# 13       TCS  18.0  1234.0
# 15   Infosys  23.0  3000.0
# 16       CTS  23.0  3030.0
# 17   Infosys  34.0  5000.0
# 20   Infosys  37.0  3045.0
# 21       CTS  50.0  3184.0
# 22   Infosys  21.0  4824.0
# 23       CTS   NaN  5835.0
# 25       CTS  23.0  8943.0
# 26   Infosys  34.0  8345.0
# 27       TCS  45.0  9284.0
# 29       TCS  35.0  2034.0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df.rename({''})
